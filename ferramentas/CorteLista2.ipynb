# %%
import pandas as pd

# %%
planilha = pd.read_excel("listaCompletaJogos.xlsx")
rm_coluna = planilha.drop(columns=["link", "image","GameFAQs","bayesian avg",	"Unnamed: 11",	"Unnamed: 12",	"Unnamed: 13",	"Unnamed: 14"])
display(rm_coluna)
rm_coluna.to_excel("InfoJogos.xlsx")
# Out:
#            id                                    title platform  year  \
# 0      915692                       Super Mario Galaxy      WII  2007
# 1      200275                      Super Mario Odyssey       NS  2017
# 2      805605                       Grand Theft Auto V     XONE  2014
# 3      189707  The Legend of Zelda: Breath of the Wild       NS  2017
# 4      960551                     Super Mario Galaxy 2      WII  2010
# ...       ...                                      ...      ...   ...
# 28860  950898                Ride to Hell: Retribution     X360  2013
# 28861  196888                                 Catfight       PC  1996
# 28862  950896                Ride to Hell: Retribution       PC  2013
# 28863  835621            Haunted House: Cryptic Graves       PC  2014
# 28864  919220           Big Rigs: Over the Road Racing       PC  2003
#
#        avg score  reviews                                 developer
# ...

# %%
# !pip install pandas
# !pip install openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
