# %%
import pandas as pd

# %%
planilha = pd.read_excel('listaCompletaJogos.xlsx')
display(planilha)
# Out:
#              id                                    title platform    year  \
# 0      915692.0                       Super Mario Galaxy      WII  2007.0
# 1      200275.0                      Super Mario Odyssey       NS  2017.0
# 2      805605.0                       Grand Theft Auto V     XONE  2014.0
# 3      189707.0  The Legend of Zelda: Breath of the Wild       NS  2017.0
# 4      960551.0                     Super Mario Galaxy 2      WII  2010.0
# ...         ...                                      ...      ...     ...
# 28860  950898.0                Ride to Hell: Retribution     X360  2013.0
# 28861  196888.0                                 Catfight       PC  1996.0
# 28862  950896.0                Ride to Hell: Retribution       PC  2013.0
# 28863  835621.0            Haunted House: Cryptic Graves       PC  2014.0
# 28864  919220.0           Big Rigs: Over the Road Racing       PC  2003.0
#
#        avg score  reviews                                 developer  \
# ...

# %%
jg2013 = planilha[planilha["year"] <= 2013]
display(jg2013)
# Out:
#              id                                 title platform    year  \
# 0      915692.0                    Super Mario Galaxy      WII  2007.0
# 4      960551.0                  Super Mario Galaxy 2      WII  2010.0
# 5      197771.0  The Legend of Zelda: Ocarina of Time      N64  1998.0
# 6      933036.0                   Grand Theft Auto IV      PS3  2008.0
# 8      634490.0                    Grand Theft Auto V      PS3  2013.0
# ...         ...                                   ...      ...     ...
# 28859  374901.0            Hellboy: Dogs of the Night       PC  2001.0
# 28860  950898.0             Ride to Hell: Retribution     X360  2013.0
# 28861  196888.0                              Catfight       PC  1996.0
# 28862  950896.0             Ride to Hell: Retribution       PC  2013.0
# 28864  919220.0        Big Rigs: Over the Road Racing       PC  2003.0
#
#        avg score  reviews                                 developer  \
# ...

# %%
jg_ps1 = jg2013[jg2013["platform"] == "PS"]
display(jg_ps1)
# Out:
#              id                               title platform    year  \
# 26     198900.0                            Tekken 3       PS  1998.0
# 48     197468.0                        Gran Turismo       PS  1998.0
# 50     199061.0            Tony Hawk's Pro Skater 2       PS  2000.0
# 81     199318.0                          Wipeout XL       PS  1996.0
# 93     199060.0              Tony Hawk's Pro Skater       PS  1999.0
# ...         ...                                 ...      ...     ...
# 28653  196640.0       Armorines: Project S.W.A.R.M.       PS  2000.0
# 28668  915228.0             X-Bladez: Inline Skater       PS  2002.0
# 28750  197002.0            The Crow: City of Angels       PS  1997.0
# 28797  915143.0               Beyblade: Let it Rip!       PS  2002.0
# 28810  256203.0  Batman Beyond: Return of the Joker       PS  2000.0
#
#        avg score  reviews                                   developer  \
# ...

# %%
jg_ps2 = jg2013[jg2013["platform"] == "PS2"]
display(jg_ps2)
# Out:
#              id                                              title platform  \
# 19     925156.0                                    Resident Evil 4      PS2
# 29     466217.0                               Grand Theft Auto III      PS2
# 32     914983.0                      Grand Theft Auto: San Andreas      PS2
# 35     913941.0                Metal Gear Solid 2: Sons of Liberty      PS2
# 45     197470.0                             Gran Turismo 3: A-Spec      PS2
# ...         ...                                                ...      ...
# 28724  919540.0                                     Knight Rider 2      PS2
# 28725  942011.0  George of the Jungle and the Search for the Se...      PS2
# 28742  932365.0                       Earache Extreme Metal Racing      PS2
# 28751  919566.0                                         Miami Vice      PS2
# 28854  936770.0                     Little Britain: The Video Game      PS2
#
#          year  avg score  reviews  \
# ...

# %%
jg_ps_ps2 = jg2013[jg2013["platform"].isin(["PS", "PS2"])]
display(jg_ps_ps2)
# Out:
#              id                                title platform    year  \
# 19     925156.0                      Resident Evil 4      PS2  2005.0
# 26     198900.0                             Tekken 3       PS  1998.0
# 29     466217.0                 Grand Theft Auto III      PS2  2001.0
# 32     914983.0        Grand Theft Auto: San Andreas      PS2  2004.0
# 35     913941.0  Metal Gear Solid 2: Sons of Liberty      PS2  2001.0
# ...         ...                                  ...      ...     ...
# 28750  197002.0             The Crow: City of Angels       PS  1997.0
# 28751  919566.0                           Miami Vice      PS2  2004.0
# 28797  915143.0                Beyblade: Let it Rip!       PS  2002.0
# 28810  256203.0   Batman Beyond: Return of the Joker       PS  2000.0
# 28854  936770.0       Little Britain: The Video Game      PS2  2007.0
#
#        avg score  reviews                                    developer  \
# ...

# %%
lista_jogos = jg_ps_ps2.drop(columns=["id", "link",	"GameFAQs",	"bayesian avg",	"Unnamed: 11",	"Unnamed: 12",	"Unnamed: 13",	"Unnamed: 14"])
display(lista_jogos)
# Out:
#                                      title platform    year  avg score  \
# 19                         Resident Evil 4      PS2  2005.0      95.85
# 26                                Tekken 3       PS  1998.0      95.80
# 29                    Grand Theft Auto III      PS2  2001.0      95.19
# 32           Grand Theft Auto: San Andreas      PS2  2004.0      95.08
# 35     Metal Gear Solid 2: Sons of Liberty      PS2  2001.0      95.09
# ...                                    ...      ...     ...        ...
# 28750             The Crow: City of Angels       PS  1997.0      23.50
# 28751                           Miami Vice      PS2  2004.0      25.08
# 28797                Beyblade: Let it Rip!       PS  2002.0      22.50
# 28810   Batman Beyond: Return of the Joker       PS  2000.0      22.12
# 28854       Little Britain: The Video Game      PS2  2007.0      16.00
#
#        reviews                                    developer  \
# ...

# %%
lista_jogos.to_excel("Lista_Jogos.xlsx")
